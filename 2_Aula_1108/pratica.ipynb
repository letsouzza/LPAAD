# %% [markdown]
# ## Comando If/Else- Prática 11/08

# %% [markdown]
# ### 1. Solicitar Temperatura

# %%
temperatura = float(input("Digite a temperatura atual:"))

if temperatura > 30:
    print("Recomendado você se hidratar! Alta temperatura.")
# Out:
# Recomendado você se hidratar! Alta temperatura.

# %% [markdown]
# ### 2. Par ou Ímpar

# %%
numero = int(input("Digite um número:"))

if numero % 2 == 0:
    print(f'Número {numero} é Par')
else:
    print(f'Número {numero} é Ímpar')
# Out:
# Número 32 é Par

# %% [markdown]
# ### *Operadores Relacionais*

# %% [markdown]
# * **Igual a (==):** Verifica se dois valores são iguais.
# * **Diferente de (!=):** Verifica se dois valores não são iguais.
# * **Maior que (>):** Verifica se o primeiro valor é maior que o segundo.
# * **Menor que (<):** Verifica se o primeiro valor é menor que o segundo.
# * **Maior ou igual a (>=):** Verifica se o primeiro valor é maior ou igual ao segundo.
# * **Menor ou igual a (<=):** Verifica se o primeiro valor é menor ou igual ao segundo

# %% [markdown]
# ### 3. Verificar saldo

# %%
saldo = float(input("Digite o seu saldo atual:"))
valor = float(input("Digit o valor de transação:"))
saldo_suficiente= False 

if saldo >= valor:
    saldo_suficiente= True 
    print(f'Transação autorizada. \n Saldo atual: {saldo-valor:.2f}')
else:
    print("Transação negada: saldo insuficiente!")

print("Saldo suficiente:", saldo_suficiente)
# Out:
# Transação autorizada.
#  Saldo atual: 9.50
# Saldo suficiente: True

# %% [markdown]
# ### *Operadores Lógicos*

# %% [markdown]
# ![Operadores lógicos](https://minio.scielo.br/documentstore/1980-265X/SyhRj7G4RFHVh3MZtHDSGQx/ae25b58906dd30038a4ea394cee4c5e100cb0c47.jpg)

# %% [markdown]
# ### 4. Lista de Produção

# %%
producao = [120, 135, 128, 142, 150]

producao.append(int(input("Digite o valor de produção:")))
producao.append(int(input("Digite o valor de produção:")))
producao.append(int(input("Digite o valor de produção:")))
producao.append(int(input("Digite o valor de produção:")))

quantidade = len(producao)

print("Quantidade de itens de produção:", quantidade)
# Out:
# Quantidade de itens de produção: 9
